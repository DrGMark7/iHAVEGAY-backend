# %%
import pandas as pd

cpu_id = pd.read_json("src/database/json/cpu_id.json")
cpu_spec = pd.read_json("src/database/json/cpu_spec.json")

cpu = pd.merge(cpu_id, cpu_spec, on="cpu_id")

# %%
cpu_add_to_database = cpu.drop(columns=["title"])
for i in range(len(cpu_add_to_database)):
    cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
cpu_add_to_database.to_json("src/database/json/cpu.json", orient="records", indent=4)
# Out:
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))
# /var/folders/hf/8xz7f04171x0plfvhtmmdqxw0000gn/T/ipykernel_51869/3977981073.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu_add_to_database['price'][i] = int(cpu_add_to_database['price'][i].replace("NT$", "").replace(",", ""))

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017/")
db = client["database"]
collection = db["cpu"]
collection.drop()

cpu_json = cpu_add_to_database.to_dict(orient="records")
collection.insert_many(cpu_json)
# Out:
# InsertManyResult([ObjectId('67acbbdddeaf6739431431b8'), ObjectId('67acbbdddeaf6739431431b9'), ObjectId('67acbbdddeaf6739431431ba'), ObjectId('67acbbdddeaf6739431431bb'), ObjectId('67acbbdddeaf6739431431bc'), ObjectId('67acbbdddeaf6739431431bd'), ObjectId('67acbbdddeaf6739431431be'), ObjectId('67acbbdddeaf6739431431bf'), ObjectId('67acbbdddeaf6739431431c0'), ObjectId('67acbbdddeaf6739431431c1'), ObjectId('67acbbdddeaf6739431431c2'), ObjectId('67acbbdddeaf6739431431c3'), ObjectId('67acbbdddeaf6739431431c4'), ObjectId('67acbbdddeaf6739431431c5'), ObjectId('67acbbdddeaf6739431431c6'), ObjectId('67acbbdddeaf6739431431c7'), ObjectId('67acbbdddeaf6739431431c8'), ObjectId('67acbbdddeaf6739431431c9'), ObjectId('67acbbdddeaf6739431431ca'), ObjectId('67acbbdddeaf6739431431cb'), ObjectId('67acbbdddeaf6739431431cc'), ObjectId('67acbbdddeaf6739431431cd'), ObjectId('67acbbdddeaf6739431431ce'), ObjectId('67acbbdddeaf6739431431cf'), ObjectId('67acbbdddeaf6739431431d0'), ObjectId('67acbbdddeaf6739431431d1'), ObjectId('67acbbdddeaf6739431431d2'), ObjectId('67acbbdddeaf6739431431d3'), ObjectId('67acbbdddeaf6739431431d4'), ObjectId('67acbbdddeaf6739431431d5'), ObjectId('67acbbdddeaf6739431431d6'), ObjectId('67acbbdddeaf6739431431d7'), ObjectId('67acbbdddeaf6739431431d8'), ObjectId('67acbbdddeaf6739431431d9'), ObjectId('67acbbdddeaf6739431431da'), ObjectId('67acbbdddeaf6739431431db'), ObjectId('67acbbdddeaf6739431431dc'), ObjectId('67acbbdddeaf6739431431dd'), ObjectId('67acbbdddeaf6739431431de'), ObjectId('67acbbdddeaf6739431431df'), ObjectId('67acbbdddeaf6739431431e0'), ObjectId('67acbbdddeaf6739431431e1'), ObjectId('67acbbdddeaf6739431431e2'), ObjectId('67acbbdddeaf6739431431e3'), ObjectId('67acbbdddeaf6739431431e4'), ObjectId('67acbbdddeaf6739431431e5'), ObjectId('67acbbdddeaf6739431431e6'), ObjectId('67acbbdddeaf6739431431e7'), ObjectId('67acbbdddeaf6739431431e8'), ObjectId('67acbbdddeaf6739431431e9'), ObjectId('67acbbdddeaf6739431431ea'), ObjectId('67acbbdddeaf6739431431eb'), ObjectId('67acbbdddeaf6739431431ec'), ObjectId('67acbbdddeaf6739431431ed'), ObjectId('67acbbdddeaf6739431431ee'), ObjectId('67acbbdddeaf6739431431ef'), ObjectId('67acbbdddeaf6739431431f0'), ObjectId('67acbbdddeaf6739431431f1'), ObjectId('67acbbdddeaf6739431431f2'), ObjectId('67acbbdddeaf6739431431f3'), ObjectId('67acbbdddeaf6739431431f4'), ObjectId('67acbbdddeaf6739431431f5'), ObjectId('67acbbdddeaf6739431431f6'), ObjectId('67acbbdddeaf6739431431f7'), ObjectId('67acbbdddeaf6739431431f8'), ObjectId('67acbbdddeaf6739431431f9')], acknowledged=True)

# %%
# View Database
cursor = collection.find({}) #. Query everything in the collection
cursor = collection.find({}).limit(5) #. Query the first 5 documents in the collection
cursor = collection.find({}).sort("price", 1) #. Sort the documents in ascending order of price
query = {"price": {"$gt": 10000}} #. Query documents with price greater than 10000
cursor = collection.find(query).sort("price", 1)
cpu_list = list(cursor)
cpu_list
# Out:
# [{'_id': ObjectId('67acbbdddeaf6739431431e9'),
#   'cpu_id': 10050,
#   'price': 10190,
#   'brand': 'AMD',
#   'Socket': 'AM5'},
#  {'_id': ObjectId('67acbbdddeaf6739431431ce'),
#   'cpu_id': 10023,
#   'price': 10200,
#   'brand': 'Intel',
#   'Socket': '1700'},
#  {'_id': ObjectId('67acbbdddeaf6739431431c7'),
#   'cpu_id': 10016,
#   'price': 10400,
#   'brand': 'Intel',
#   'Socket': '1700'},
#  {'_id': ObjectId('67acbbdddeaf6739431431f5'),
#   'cpu_id': 10062,
#   'price': 10800,
#   'brand': 'Intel',
#   'Socket': '1851'},
#  {'_id': ObjectId('67acbbdddeaf6739431431e6'),
#   'cpu_id': 10047,
#   'price': 11090,
#   'brand': 'AMD',
#   'Socket': 'AM5'},
#  {'_id': ObjectId('67acbbdddeaf6739431431e1'),
#   'cpu_id': 10042,
#   'price': 11400,
#   'brand': 'Intel',
#   'Socket': '1700'},
#  {'_id': ObjectId('67acbbdddeaf6739431431d5'),
#   'cpu_id': 10030,
#   'price': 11990,
#   'brand': 'AMD',
#   'Socket': 'AM5'},
#  {'_id': ObjectId('67acbbdddeaf6739431431e3'),
#   'cpu_id': 10044,
#   'price': 12900,
#   'brand': 'Intel',
#   'Socket': '1700'},
#  {'_id': ObjectId('67acbbdddeaf6739431431db'),
#   'cpu_id': 10036,
#   'price': 13990,
#   'brand': 'AMD',
#   'Socket': 'AM5'},
#  {'_id': ObjectId('67acbbdddeaf6739431431cd'),
#   'cpu_id': 10022,
#   'price': 14100,
#   'brand': 'Intel',
#   'Socket': '1700'},
#  {'_id': ObjectId('67acbbdddeaf6739431431e2'),
#   'cpu_id': 10043,
#   'price': 14190,
#   'brand': 'AMD',
#   'Socket': 'AM5'},
#  {'_id': ObjectId('67acbbdddeaf6739431431ed'),
#   'cpu_id': 10054,
#   'price': 14300,
#   'brand': 'Intel',
#   'Socket': '1851'},
#  {'_id': ObjectId('67acbbdddeaf6739431431e0'),
#   'cpu_id': 10041,
#   'price': 14500,
#   'brand': 'Intel',
#   'Socket': '1700'},
#  {'_id': ObjectId('67acbbdddeaf6739431431ec'),
#   'cpu_id': 10053,
#   'price': 14900,
#   'brand': 'Intel',
#   'Socket': '1851'},
#  {'_id': ObjectId('67acbbdddeaf6739431431ca'),
#   'cpu_id': 10019,
#   'price': 14900,
#   'brand': 'Intel',
#   'Socket': '1700'},
#  {'_id': ObjectId('67acbbdddeaf6739431431f9'),
#   'cpu_id': 10066,
#   'price': 15200,
#   'brand': 'Intel',
#   'Socket': '1851'},
#  {'_id': ObjectId('67acbbdddeaf6739431431f0'),
#   'cpu_id': 10057,
#   'price': 17490,
#   'brand': 'AMD',
#   'Socket': 'AM5'},
#  {'_id': ObjectId('67acbbdddeaf6739431431eb'),
#   'cpu_id': 10052,
#   'price': 17900,
#   'brand': 'Intel',
#   'Socket': '1700'},
#  {'_id': ObjectId('67acbbdddeaf6739431431c2'),
#   'cpu_id': 10011,
#   'price': 17900,
#   'brand': 'AMD',
#   'Socket': 'AM5'},
#  {'_id': ObjectId('67acbbdddeaf6739431431d2'),
#   'cpu_id': 10027,
#   'price': 18800,
#   'brand': 'Intel',
#   'Socket': '1700'},
#  {'_id': ObjectId('67acbbdddeaf6739431431d8'),
#   'cpu_id': 10033,
#   'price': 20990,
#   'brand': 'AMD',
#   'Socket': 'AM5'},
#  {'_id': ObjectId('67acbbdddeaf6739431431e5'),
#   'cpu_id': 10046,
#   'price': 24690,
#   'brand': 'AMD',
#   'Socket': 'AM5'}]

# %%
from src.database.database import Database
from src.database.schemas import all_cpu

collection = Database.get_collection('CPUs')
datas = collection.find({}, {"_id": 0})
for data in datas:
    print(data)
# Out:
# {'cpu_id': 10001, 'title': 'AMD RYZEN 5 5600X 3.7 GHz (SOCKET AM4)', 'price': 4890, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210825104649_43471_21_2.jpg'}
# {'cpu_id': 10002, 'title': 'INTEL CORE I5-12400F 2.5 GHz (SOCKET LGA 1700)', 'price': 3840, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022010509243450623_1.jpg'}
# {'cpu_id': 10003, 'title': 'INTEL CORE I5-10400F 2.9 GHz (SOCKET LGA 1200)', 'price': 3660, 'Socket': '1200', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2020060310001739905_1.png'}
# {'cpu_id': 10004, 'title': 'INTEL CORE I5-10400 2.9 GHz (SOCKET LGA 1200)', 'price': 4590, 'Socket': '1200', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2020051316574639061_1.png'}
# {'cpu_id': 10005, 'title': 'INTEL CORE I5-13500 - 14C 20T 1.8-4.8GHz (INTEL SOCKET 1700)', 'price': 8690, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022122610182056974_1.jpg'}
# {'cpu_id': 10006, 'title': 'INTEL CORE I3-12100F 3.3 GHz (SOCKET LGA 1700)', 'price': 2850, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022010508500650622_1.jpg'}
# {'cpu_id': 10007, 'title': 'AMD RYZEN 3 3200G 3.6 GHz (SOCKET AM4)', 'price': 1990, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210827130806_34578_23_1.jpg'}
# {'cpu_id': 10008, 'title': 'AMD RYZEN 5 3400G 3.7 GHz (SOCKET AM4)', 'price': 2890, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20191120170459_34586_24_1.png'}
# {'cpu_id': 10009, 'title': 'AMD RYZEN 5 5600G 3.9 GHz (SOCKET AM4)', 'price': 4890, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210825151834_47944_21_1.jpg'}
# {'cpu_id': 10010, 'title': 'INTEL CORE I5-12400 2.5 GHz (SOCKET LGA 1700)', 'price': 4980, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022010509312850624_1.jpg'}
# {'cpu_id': 10011, 'title': 'AMD RYZEN 7 7800X3D 4.2 GHz (SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 17900, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023041914270158961_1.jpg'}
# {'cpu_id': 10012, 'title': 'INTEL CORE I5-13400F - 10C 16T 1.8-4.6GHz (INTEL SOCKET 1700)', 'price': 5290, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022122610011856972_1.jpg'}
# {'cpu_id': 10013, 'title': 'INTEL CORE I3-10105F 3.7 GHz (SOCKET LGA 1200)', 'price': 2490, 'Socket': '1200', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2021033109120546086_1.jpg'}
# {'cpu_id': 10014, 'title': 'AMD RYZEN 7 5700G 3.8 GHz (SOCKET AM4)', 'price': 7290, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210825152410_47945_21_2.jpg'}
# {'cpu_id': 10015, 'title': 'AMD RYZEN 5 5600 3.5 GHz (SOCKET AM4)', 'price': 3690, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022040514151552538_1.jpg'}
# {'cpu_id': 10016, 'title': 'INTEL CORE I7-12700K 3.6 GHz (SOCKET LGA 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 10400, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2021102715324149470_1.png'}
# {'cpu_id': 10017, 'title': 'AMD ATHLON 3000G 3.5 GHz (SOCKET AM4)', 'price': 1790, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210827132430_35827_23_1.jpg'}
# {'cpu_id': 10018, 'title': 'AMD RYZEN 5 4500 3.6 GHz (SOCKET AM4)', 'price': 2590, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022050310524952893_1.jpg'}
# {'cpu_id': 10019, 'title': 'INTEL CORE I7-13700K - 16C 24T 2.5-5.4GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 14900, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022092909541955462_1.jpg'}
# {'cpu_id': 10020, 'title': 'INTEL CORE I7-12700F 2.1 GHz (SOCKET LGA 1700)', 'price': 9490, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022010510074050627_1.jpg'}
# {'cpu_id': 10021, 'title': 'AMD RYZEN 5 5500 3.6 GHz (SOCKET AM4)', 'price': 2790, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022040514004252535_1.jpg'}
# {'cpu_id': 10022, 'title': 'INTEL CORE I7-14700K - 20C 28T 2.5-5.6GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 14100, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023101615255663038_1.png'}
# {'cpu_id': 10023, 'title': 'INTEL CORE I7-12700 2.1 GHz (SOCKET LGA 1700)', 'price': 10200, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022011316503150843_1.jpg'}
# {'cpu_id': 10024, 'title': 'AMD RYZEN 7 5700X 3.4 GHz (SOCKET AM4) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 7390, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022040514204652539_1.jpg'}
# {'cpu_id': 10025, 'title': 'AMD RYZEN 5 4600G 3.7 GHz (SOCKET AM4)', 'price': 3690, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20230913163526_53370_344_1.jpg'}
# {'cpu_id': 10026, 'title': 'INTEL CORE I3-12100 3.3 GHz (SOCKET LGA 1700)', 'price': 3740, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022021010031651545_1.jpg'}
# {'cpu_id': 10027, 'title': 'INTEL CORE I9-14900K - 24C 32T 2.4-6.0GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 18800, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023101615262063040_1.png'}
# {'cpu_id': 10028, 'title': 'AMD RYZEN 5 7600 3.8 GHz (SOCKET AM5)', 'price': 7790, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20230111142106_57299_66_1.jpg'}
# {'cpu_id': 10029, 'title': 'INTEL CORE I5-14500 - 14C 20T 1.9-5.0GHz (INTEL SOCKET 1700)', 'price': 8840, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024010614385764701_1.jpg'}
# {'cpu_id': 10030, 'title': 'AMD RYZEN 7 7700X 4.5 GHz (SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 11990, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022092613123755402_1.jpg'}
# {'cpu_id': 10031, 'title': 'INTEL CORE I3-10105 3.7 GHz (SOCKET LGA 1200)', 'price': 3390, 'Socket': '1200', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2021050813585046521_1.png'}
# {'cpu_id': 10032, 'title': 'INTEL CORE I5-13400 - 10C 16T 1.8-4.6GHz (INTEL SOCKET 1700)', 'price': 6590, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022122609520956970_1.jpg'}
# {'cpu_id': 10033, 'title': 'AMD RYZEN 9 7950X 4.5 GHz (SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 20990, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022092613555155412_1.jpg'}
# {'cpu_id': 10034, 'title': 'AMD RYZEN 7 5700X3D (SOCKET AM4) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 9690, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013016262265148_1.jpg'}
# {'cpu_id': 10035, 'title': 'INTEL CORE I5-14400F - 10C 16T 1.8-4.7GHz (INTEL SOCKET 1700)', 'price': 5790, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024010614561764702_1.jpg'}
# {'cpu_id': 10036, 'title': 'AMD RYZEN 9 7900X 4.7 GHz (SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 13990, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022092613431555409_1.jpg'}
# {'cpu_id': 10037, 'title': 'INTEL CORE I5-14600K - 14C 20T 2.6-5.3GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 9900, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023101615234563036_1.png'}
# {'cpu_id': 10038, 'title': 'INTEL PENTIUM GOLD G6405 4.1 GHz (SOCKET LGA 1200)', 'price': 2390, 'Socket': '1200', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210629133625_47414_66_1.png'}
# {'cpu_id': 10039, 'title': 'INTEL CORE I3-13100 - 4C 8T 3.4-4.5GHz (INTEL SOCKET 1700)', 'price': 4250, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022122609291156966_1.jpg'}
# {'cpu_id': 10040, 'title': 'INTEL CORE I3-13100F - 4C 8T 3.4-4.5GHz (INTEL SOCKET 1700)', 'price': 3190, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022122609455856968_1.jpg'}
# {'cpu_id': 10041, 'title': 'INTEL CORE I7-13700KF - 16C 24T 2.5-5.4GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 14500, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022092910030055463_1.jpg'}
# {'cpu_id': 10042, 'title': 'INTEL CORE I7-14700F - 20C 28T 1.5-5.4GHz (INTEL SOCKET 1700)', 'price': 11400, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024010614174864698_1.jpg'}
# {'cpu_id': 10043, 'title': 'AMD RYZEN 9 7900 3.7 GHz (SOCKET AM5)', 'price': 14190, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20230111142142_57303_66_1.jpg'}
# {'cpu_id': 10044, 'title': 'INTEL CORE I7-14700KF - 20C 28T 2.5-5.6GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 12900, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023101615260863039_1.png'}
# {'cpu_id': 10045, 'title': 'AMD RYZEN 5 8500G (SOCKET AM5)', 'price': 6590, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013116481665211_1.jpg'}
# {'cpu_id': 10046, 'title': 'AMD RYZEN 9 9950X - 16C 32T 4.3-5.7GHz (AMD SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 24690, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024081409110169826_1.jpg'}
# {'cpu_id': 10047, 'title': 'AMD RYZEN 7 8700G (SOCKET AM5)', 'price': 11090, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013116015665208_1.jpg'}
# {'cpu_id': 10048, 'title': 'AMD RYZEN 5 8600G (SOCKET AM5)', 'price': 7690, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013116182465209_1.jpg'}
# {'cpu_id': 10049, 'title': 'AMD RYZEN 7 5700 (SOCKET AM4)', 'price': 5490, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013017025665152_1.jpg'}
# {'cpu_id': 10050, 'title': 'AMD RYZEN 5 9600X - 6C 12T 3.9-5.4GHz (AMD SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 10190, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024080913172569751_1.jpg'}
# {'cpu_id': 10051, 'title': 'AMD RYZEN 5 7500F - 6C 12T 3.7-5.0GHz (AMD SOCKET AM5)', 'price': 6190, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20240801150411_69543_66_1.jpg'}
# {'cpu_id': 10052, 'title': 'INTEL CORE I9-14900KF - 24C 32T 2.4-6.0GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 17900, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023101615263263041_1.png'}
# {'cpu_id': 10053, 'title': 'INTEL CORE ULTRA 7 265K - 20C 20T 3.3-5.5GHz (INTEL SOCKET 1851) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 14900, 'Socket': '1851', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024100909443071188_1.jpg'}
# {'cpu_id': 10054, 'title': 'INTEL CORE ULTRA 7 265KF - 20C 20T 3.3-5.5GHz (INTEL SOCKET 1851) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 14300, 'Socket': '1851', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024100909485871189_1.jpg'}
# {'cpu_id': 10055, 'title': 'AMD RYZEN 5 5500GT (SOCKET AM4)', 'price': 4390, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013114435665201_1.JPG'}
# {'cpu_id': 10056, 'title': 'INTEL CORE I3-14100 - 4C 8T 3.5-4.7GHz (INTEL SOCKET 1700)', 'price': 4190, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024010615511864706_1.jpg'}
# {'cpu_id': 10057, 'title': 'AMD RYZEN 9 9900X - 12C 24T 4.4-5.6GHz (AMD SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 17490, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024081408465069823_1.jpg'}
# {'cpu_id': 10058, 'title': 'AMD RYZEN 5 8400F - 6C 12T 4.2-4.7GHz (AMD SOCKET AM5)', 'price': 5890, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024060511023667749_1.jpg'}
# {'cpu_id': 10059, 'title': 'INTEL CORE I3-14100F - 4C 8T 3.5-4.7GHz (INTEL SOCKET 1700)', 'price': 3790, 'Socket': '1700', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024010615460964705_1.jpg'}
# {'cpu_id': 10060, 'title': 'AMD RYZEN 5 5600GT (SOCKET AM4)', 'price': 4990, 'Socket': 'AM4', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013114232465197_1.JPG'}
# {'cpu_id': 10061, 'title': 'AMD RYZEN 7 8700F - 8C 16T 4.1-5.0GHz (AMD SOCKET AM5)', 'price': 9890, 'Socket': 'AM5', 'brand': 'AMD', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024060511522267756_1.jpg'}
# {'cpu_id': 10062, 'title': 'INTEL CORE ULTRA 5 245KF - 14C 14T 3.6-5.2GHz (INTEL SOCKET 1851) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'price': 10800, 'Socket': '1851', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024100909155571186_1.jpg'}
# {'cpu_id': 10063, 'title': 'INTEL CORE ULTRA 5 225F - 10C 10T 3.3-4.9GHz (INTEL SOCKET 1851)', 'price': 8990, 'Socket': '1851', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20250206131531_73576_66_1.jpg'}
# {'cpu_id': 10064, 'title': 'INTEL CORE ULTRA 5 235 - 14C 14T 3.4-5GHz (INTEL SOCKET 1851)', 'price': 9900, 'Socket': '1851', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20250206131553_73578_66_1.jpg'}
# {'cpu_id': 10065, 'title': 'INTEL CORE ULTRA 5 225 - 10C 10T 3.3-4.9GHz (INTEL SOCKET 1851)', 'price': 9590, 'Socket': '1851', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20250206131508_73573_66_1.jpg'}
# {'cpu_id': 10066, 'title': 'INTEL CORE ULTRA 7 265 - 20C 20T 1.8-5.3GHz (INTEL SOCKET 1851)', 'price': 15200, 'Socket': '1851', 'brand': 'Intel', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2025020614114074210_1.jpg'}

# %%
import pandas as pd
import numpy as np

arr = ['cpu', 'case', 'gpu', 'm2', 'mainboard', 'psu', 'ram', 'ssd']
for i in range(len(arr)):
    df = pd.read_json(r"C:\Users\WINDOWS 11\OneDrive\เดสก์ท็อป\iHAVEGAY-backend\src\database\json\{}_edited.json".format(arr[i]))
    df = df.rename(columns={f"{arr[i]}_id":"productID"})
    df["price"] = df["price"].str.replace(",", "").astype(int)
    df["quantity"] = np.random.randint(100, size=len(df))

    df.to_json(r"C:\Users\WINDOWS 11\OneDrive\เดสก์ท็อป\iHAVEGAY-backend\src\database\json\{}.json".format(arr[i]), orient="records")

# %%
df = pd.read_json(r"C:\Users\WINDOWS 11\OneDrive\เดสก์ท็อป\iHAVEGAY-backend\src\database\json\ram.json")
arr = ["speed","number_of_DIMMs"]
for i in range(len(arr)):
    df[arr[i]] = df[arr[i]].replace("-", "0").str.replace(",", "").astype(int)
df.to_json(r"C:\Users\WINDOWS 11\OneDrive\เดสก์ท็อป\iHAVEGAY-backend\src\database\json\ram.json", orient="records")

# %%
df = pd.read_json(r"C:\Users\WINDOWS 11\OneDrive\เดสก์ท็อป\iHAVEGAY-backend\src\database\json\cpu.json")
df = df.rename(columns={"Socket":"socket"})
df.to_json(r"C:\Users\WINDOWS 11\OneDrive\เดสก์ท็อป\iHAVEGAY-backend\src\database\json\cpu.json", orient="records")

# %%
import src.database.manage_database as hm

hm.HardwareManager().add_cpu(r"C:\Users\WINDOWS 11\OneDrive\เดสก์ท็อป\iHAVEGAY-backend\src\database\json\cpu.json")
# Out:
# Invalid data: {'productID': 10001, 'title': 'AMD RYZEN 5 5600X 3.7 GHz (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210825104649_43471_21_2.jpg', 'price': 4890, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 28} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10001, 'tit...: 'AMD', 'quantity': 28}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10002, 'title': 'INTEL CORE I5-12400F 2.5 GHz (SOCKET LGA 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022010509243450623_1.jpg', 'price': 3840, 'socket': '1700', 'brand': 'Intel', 'quantity': 37} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10002, 'tit...'Intel', 'quantity': 37}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10003, 'title': 'INTEL CORE I5-10400F 2.9 GHz (SOCKET LGA 1200)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2020060310001739905_1.png', 'price': 3660, 'socket': '1200', 'brand': 'Intel', 'quantity': 81} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10003, 'tit...'Intel', 'quantity': 81}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10004, 'title': 'INTEL CORE I5-10400 2.9 GHz (SOCKET LGA 1200)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2020051316574639061_1.png', 'price': 4590, 'socket': '1200', 'brand': 'Intel', 'quantity': 4} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10004, 'tit... 'Intel', 'quantity': 4}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10005, 'title': 'INTEL CORE I5-13500 - 14C 20T 1.8-4.8GHz (INTEL SOCKET 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022122610182056974_1.jpg', 'price': 8690, 'socket': '1700', 'brand': 'Intel', 'quantity': 73} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10005, 'tit...'Intel', 'quantity': 73}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10006, 'title': 'INTEL CORE I3-12100F 3.3 GHz (SOCKET LGA 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022010508500650622_1.jpg', 'price': 2850, 'socket': '1700', 'brand': 'Intel', 'quantity': 27} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10006, 'tit...'Intel', 'quantity': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10007, 'title': 'AMD RYZEN 3 3200G 3.6 GHz (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210827130806_34578_23_1.jpg', 'price': 1990, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 77} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10007, 'tit...: 'AMD', 'quantity': 77}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10008, 'title': 'AMD RYZEN 5 3400G 3.7 GHz (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20191120170459_34586_24_1.png', 'price': 2890, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 71} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10008, 'tit...: 'AMD', 'quantity': 71}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10009, 'title': 'AMD RYZEN 5 5600G 3.9 GHz (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210825151834_47944_21_1.jpg', 'price': 4890, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 27} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10009, 'tit...: 'AMD', 'quantity': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10010, 'title': 'INTEL CORE I5-12400 2.5 GHz (SOCKET LGA 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022010509312850624_1.jpg', 'price': 4980, 'socket': '1700', 'brand': 'Intel', 'quantity': 71} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10010, 'tit...'Intel', 'quantity': 71}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10011, 'title': 'AMD RYZEN 7 7800X3D 4.2 GHz (SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023041914270158961_1.jpg', 'price': 17900, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 30} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10011, 'tit...: 'AMD', 'quantity': 30}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10012, 'title': 'INTEL CORE I5-13400F - 10C 16T 1.8-4.6GHz (INTEL SOCKET 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022122610011856972_1.jpg', 'price': 5290, 'socket': '1700', 'brand': 'Intel', 'quantity': 34} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10012, 'tit...'Intel', 'quantity': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10013, 'title': 'INTEL CORE I3-10105F 3.7 GHz (SOCKET LGA 1200)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2021033109120546086_1.jpg', 'price': 2490, 'socket': '1200', 'brand': 'Intel', 'quantity': 99} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10013, 'tit...'Intel', 'quantity': 99}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10014, 'title': 'AMD RYZEN 7 5700G 3.8 GHz (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210825152410_47945_21_2.jpg', 'price': 7290, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 67} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10014, 'tit...: 'AMD', 'quantity': 67}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10015, 'title': 'AMD RYZEN 5 5600 3.5 GHz (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022040514151552538_1.jpg', 'price': 3690, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 5} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10015, 'tit...': 'AMD', 'quantity': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10016, 'title': 'INTEL CORE I7-12700K 3.6 GHz (SOCKET LGA 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2021102715324149470_1.png', 'price': 10400, 'socket': '1700', 'brand': 'Intel', 'quantity': 63} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10016, 'tit...'Intel', 'quantity': 63}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10017, 'title': 'AMD ATHLON 3000G 3.5 GHz (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210827132430_35827_23_1.jpg', 'price': 1790, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 85} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10017, 'tit...: 'AMD', 'quantity': 85}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10018, 'title': 'AMD RYZEN 5 4500 3.6 GHz (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022050310524952893_1.jpg', 'price': 2590, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 16} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10018, 'tit...: 'AMD', 'quantity': 16}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10019, 'title': 'INTEL CORE I7-13700K - 16C 24T 2.5-5.4GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022092909541955462_1.jpg', 'price': 14900, 'socket': '1700', 'brand': 'Intel', 'quantity': 89} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10019, 'tit...'Intel', 'quantity': 89}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10020, 'title': 'INTEL CORE I7-12700F 2.1 GHz (SOCKET LGA 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022010510074050627_1.jpg', 'price': 9490, 'socket': '1700', 'brand': 'Intel', 'quantity': 74} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10020, 'tit...'Intel', 'quantity': 74}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10021, 'title': 'AMD RYZEN 5 5500 3.6 GHz (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022040514004252535_1.jpg', 'price': 2790, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 55} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10021, 'tit...: 'AMD', 'quantity': 55}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10022, 'title': 'INTEL CORE I7-14700K - 20C 28T 2.5-5.6GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023101615255663038_1.png', 'price': 14100, 'socket': '1700', 'brand': 'Intel', 'quantity': 42} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10022, 'tit...'Intel', 'quantity': 42}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10023, 'title': 'INTEL CORE I7-12700 2.1 GHz (SOCKET LGA 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022011316503150843_1.jpg', 'price': 10200, 'socket': '1700', 'brand': 'Intel', 'quantity': 26} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10023, 'tit...'Intel', 'quantity': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10024, 'title': 'AMD RYZEN 7 5700X 3.4 GHz (SOCKET AM4) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022040514204652539_1.jpg', 'price': 7390, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 17} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10024, 'tit...: 'AMD', 'quantity': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10025, 'title': 'AMD RYZEN 5 4600G 3.7 GHz (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20230913163526_53370_344_1.jpg', 'price': 3690, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 33} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10025, 'tit...: 'AMD', 'quantity': 33}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10026, 'title': 'INTEL CORE I3-12100 3.3 GHz (SOCKET LGA 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022021010031651545_1.jpg', 'price': 3740, 'socket': '1700', 'brand': 'Intel', 'quantity': 93} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10026, 'tit...'Intel', 'quantity': 93}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10027, 'title': 'INTEL CORE I9-14900K - 24C 32T 2.4-6.0GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023101615262063040_1.png', 'price': 18800, 'socket': '1700', 'brand': 'Intel', 'quantity': 40} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10027, 'tit...'Intel', 'quantity': 40}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10028, 'title': 'AMD RYZEN 5 7600 3.8 GHz (SOCKET AM5)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20230111142106_57299_66_1.jpg', 'price': 7790, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 26} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10028, 'tit...: 'AMD', 'quantity': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10029, 'title': 'INTEL CORE I5-14500 - 14C 20T 1.9-5.0GHz (INTEL SOCKET 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024010614385764701_1.jpg', 'price': 8840, 'socket': '1700', 'brand': 'Intel', 'quantity': 46} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10029, 'tit...'Intel', 'quantity': 46}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10030, 'title': 'AMD RYZEN 7 7700X 4.5 GHz (SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022092613123755402_1.jpg', 'price': 11990, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 90} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10030, 'tit...: 'AMD', 'quantity': 90}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10031, 'title': 'INTEL CORE I3-10105 3.7 GHz (SOCKET LGA 1200)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2021050813585046521_1.png', 'price': 3390, 'socket': '1200', 'brand': 'Intel', 'quantity': 12} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10031, 'tit...'Intel', 'quantity': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10032, 'title': 'INTEL CORE I5-13400 - 10C 16T 1.8-4.6GHz (INTEL SOCKET 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022122609520956970_1.jpg', 'price': 6590, 'socket': '1700', 'brand': 'Intel', 'quantity': 23} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10032, 'tit...'Intel', 'quantity': 23}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10033, 'title': 'AMD RYZEN 9 7950X 4.5 GHz (SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022092613555155412_1.jpg', 'price': 20990, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 56} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10033, 'tit...: 'AMD', 'quantity': 56}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10034, 'title': 'AMD RYZEN 7 5700X3D (SOCKET AM4) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013016262265148_1.jpg', 'price': 9690, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 51} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10034, 'tit...: 'AMD', 'quantity': 51}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10035, 'title': 'INTEL CORE I5-14400F - 10C 16T 1.8-4.7GHz (INTEL SOCKET 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024010614561764702_1.jpg', 'price': 5790, 'socket': '1700', 'brand': 'Intel', 'quantity': 41} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10035, 'tit...'Intel', 'quantity': 41}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10036, 'title': 'AMD RYZEN 9 7900X 4.7 GHz (SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022092613431555409_1.jpg', 'price': 13990, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 42} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10036, 'tit...: 'AMD', 'quantity': 42}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10037, 'title': 'INTEL CORE I5-14600K - 14C 20T 2.6-5.3GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023101615234563036_1.png', 'price': 9900, 'socket': '1700', 'brand': 'Intel', 'quantity': 60} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10037, 'tit...'Intel', 'quantity': 60}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10038, 'title': 'INTEL PENTIUM GOLD G6405 4.1 GHz (SOCKET LGA 1200)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20210629133625_47414_66_1.png', 'price': 2390, 'socket': '1200', 'brand': 'Intel', 'quantity': 10} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10038, 'tit...'Intel', 'quantity': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10039, 'title': 'INTEL CORE I3-13100 - 4C 8T 3.4-4.5GHz (INTEL SOCKET 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022122609291156966_1.jpg', 'price': 4250, 'socket': '1700', 'brand': 'Intel', 'quantity': 54} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10039, 'tit...'Intel', 'quantity': 54}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10040, 'title': 'INTEL CORE I3-13100F - 4C 8T 3.4-4.5GHz (INTEL SOCKET 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022122609455856968_1.jpg', 'price': 3190, 'socket': '1700', 'brand': 'Intel', 'quantity': 76} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10040, 'tit...'Intel', 'quantity': 76}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10041, 'title': 'INTEL CORE I7-13700KF - 16C 24T 2.5-5.4GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2022092910030055463_1.jpg', 'price': 14500, 'socket': '1700', 'brand': 'Intel', 'quantity': 63} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10041, 'tit...'Intel', 'quantity': 63}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10042, 'title': 'INTEL CORE I7-14700F - 20C 28T 1.5-5.4GHz (INTEL SOCKET 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024010614174864698_1.jpg', 'price': 11400, 'socket': '1700', 'brand': 'Intel', 'quantity': 15} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10042, 'tit...'Intel', 'quantity': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10043, 'title': 'AMD RYZEN 9 7900 3.7 GHz (SOCKET AM5)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20230111142142_57303_66_1.jpg', 'price': 14190, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 54} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10043, 'tit...: 'AMD', 'quantity': 54}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10044, 'title': 'INTEL CORE I7-14700KF - 20C 28T 2.5-5.6GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023101615260863039_1.png', 'price': 12900, 'socket': '1700', 'brand': 'Intel', 'quantity': 75} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10044, 'tit...'Intel', 'quantity': 75}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10045, 'title': 'AMD RYZEN 5 8500G (SOCKET AM5)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013116481665211_1.jpg', 'price': 6590, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 3} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10045, 'tit...': 'AMD', 'quantity': 3}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10046, 'title': 'AMD RYZEN 9 9950X - 16C 32T 4.3-5.7GHz (AMD SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024081409110169826_1.jpg', 'price': 24690, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 40} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10046, 'tit...: 'AMD', 'quantity': 40}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10047, 'title': 'AMD RYZEN 7 8700G (SOCKET AM5)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013116015665208_1.jpg', 'price': 11090, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 81} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10047, 'tit...: 'AMD', 'quantity': 81}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10048, 'title': 'AMD RYZEN 5 8600G (SOCKET AM5)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013116182465209_1.jpg', 'price': 7690, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 60} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10048, 'tit...: 'AMD', 'quantity': 60}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10049, 'title': 'AMD RYZEN 7 5700 (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013017025665152_1.jpg', 'price': 5490, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 74} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10049, 'tit...: 'AMD', 'quantity': 74}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10050, 'title': 'AMD RYZEN 5 9600X - 6C 12T 3.9-5.4GHz (AMD SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024080913172569751_1.jpg', 'price': 10190, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 65} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10050, 'tit...: 'AMD', 'quantity': 65}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10051, 'title': 'AMD RYZEN 5 7500F - 6C 12T 3.7-5.0GHz (AMD SOCKET AM5)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20240801150411_69543_66_1.jpg', 'price': 6190, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 8} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10051, 'tit...': 'AMD', 'quantity': 8}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10052, 'title': 'INTEL CORE I9-14900KF - 24C 32T 2.4-6.0GHz (INTEL SOCKET 1700) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2023101615263263041_1.png', 'price': 17900, 'socket': '1700', 'brand': 'Intel', 'quantity': 38} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10052, 'tit...'Intel', 'quantity': 38}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10053, 'title': 'INTEL CORE ULTRA 7 265K - 20C 20T 3.3-5.5GHz (INTEL SOCKET 1851) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024100909443071188_1.jpg', 'price': 14900, 'socket': '1851', 'brand': 'Intel', 'quantity': 94} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10053, 'tit...'Intel', 'quantity': 94}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10054, 'title': 'INTEL CORE ULTRA 7 265KF - 20C 20T 3.3-5.5GHz (INTEL SOCKET 1851) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024100909485871189_1.jpg', 'price': 14300, 'socket': '1851', 'brand': 'Intel', 'quantity': 74} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10054, 'tit...'Intel', 'quantity': 74}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10055, 'title': 'AMD RYZEN 5 5500GT (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013114435665201_1.JPG', 'price': 4390, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 22} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10055, 'tit...: 'AMD', 'quantity': 22}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10056, 'title': 'INTEL CORE I3-14100 - 4C 8T 3.5-4.7GHz (INTEL SOCKET 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024010615511864706_1.jpg', 'price': 4190, 'socket': '1700', 'brand': 'Intel', 'quantity': 41} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10056, 'tit...'Intel', 'quantity': 41}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10057, 'title': 'AMD RYZEN 9 9900X - 12C 24T 4.4-5.6GHz (AMD SOCKET AM5) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024081408465069823_1.jpg', 'price': 17490, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 24} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10057, 'tit...: 'AMD', 'quantity': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10058, 'title': 'AMD RYZEN 5 8400F - 6C 12T 4.2-4.7GHz (AMD SOCKET AM5)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024060511023667749_1.jpg', 'price': 5890, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 96} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10058, 'tit...: 'AMD', 'quantity': 96}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10059, 'title': 'INTEL CORE I3-14100F - 4C 8T 3.5-4.7GHz (INTEL SOCKET 1700)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024010615460964705_1.jpg', 'price': 3790, 'socket': '1700', 'brand': 'Intel', 'quantity': 61} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10059, 'tit...'Intel', 'quantity': 61}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10060, 'title': 'AMD RYZEN 5 5600GT (SOCKET AM4)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024013114232465197_1.JPG', 'price': 4990, 'socket': 'AM4', 'brand': 'AMD', 'quantity': 31} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10060, 'tit...: 'AMD', 'quantity': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10061, 'title': 'AMD RYZEN 7 8700F - 8C 16T 4.1-5.0GHz (AMD SOCKET AM5)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024060511522267756_1.jpg', 'price': 9890, 'socket': 'AM5', 'brand': 'AMD', 'quantity': 72} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10061, 'tit...: 'AMD', 'quantity': 72}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10062, 'title': 'INTEL CORE ULTRA 5 245KF - 14C 14T 3.6-5.2GHz (INTEL SOCKET 1851) (ระบบระบายความร้อนไม่รวมอยู่ในสินค้า / CPU COOLER NOT INCLUDED)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2024100909155571186_1.jpg', 'price': 10800, 'socket': '1851', 'brand': 'Intel', 'quantity': 95} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10062, 'tit...'Intel', 'quantity': 95}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10063, 'title': 'INTEL CORE ULTRA 5 225F - 10C 10T 3.3-4.9GHz (INTEL SOCKET 1851)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20250206131531_73576_66_1.jpg', 'price': 8990, 'socket': '1851', 'brand': 'Intel', 'quantity': 41} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10063, 'tit...'Intel', 'quantity': 41}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10064, 'title': 'INTEL CORE ULTRA 5 235 - 14C 14T 3.4-5GHz (INTEL SOCKET 1851)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20250206131553_73578_66_1.jpg', 'price': 9900, 'socket': '1851', 'brand': 'Intel', 'quantity': 79} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10064, 'tit...'Intel', 'quantity': 79}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10065, 'title': 'INTEL CORE ULTRA 5 225 - 10C 10T 3.3-4.9GHz (INTEL SOCKET 1851)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/20250206131508_73573_66_1.jpg', 'price': 9590, 'socket': '1851', 'brand': 'Intel', 'quantity': 83} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10065, 'tit...'Intel', 'quantity': 83}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# Invalid data: {'productID': 10066, 'title': 'INTEL CORE ULTRA 7 265 - 20C 20T 1.8-5.3GHz (INTEL SOCKET 1851)', 'imgUrl': 'https://www.jib.co.th/img_master/product/medium/2025020614114074210_1.jpg', 'price': 15200, 'socket': '1851', 'brand': 'Intel', 'quantity': 72} - Error: 1 validation error for CPU
# cpu_id
#   Field required [type=missing, input_value={'productID': 10066, 'tit...'Intel', 'quantity': 72}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# C:\Users\WINDOWS 11\AppData\Local\Temp\ipykernel_24016\1992061161.py:3: RuntimeWarning: coroutine 'Database.get_collection' was never awaited
#   hm.HardwareManager().add_cpu(r"C:\Users\WINDOWS 11\OneDrive\เดสก์ท็อป\iHAVEGAY-backend\src\database\json\cpu.json")
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
